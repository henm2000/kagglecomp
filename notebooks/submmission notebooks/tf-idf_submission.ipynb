# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/map-charting-student-math-misunderstandings/sample_submission.csv
# /kaggle/input/map-charting-student-math-misunderstandings/train.csv
# /kaggle/input/map-charting-student-math-misunderstandings/test.csv
# /kaggle/input/tfidf1/scikitlearn/1/2/tfidf_upload/preprocess.py
# /kaggle/input/tfidf1/scikitlearn/1/2/tfidf_upload/clf_category.pkl
# /kaggle/input/tfidf1/scikitlearn/1/2/tfidf_upload/tfidf_misconception.pkl
# /kaggle/input/tfidf1/scikitlearn/1/2/tfidf_upload/tfidf_category.pkl
# /kaggle/input/tfidf1/scikitlearn/1/2/tfidf_upload/clf_misconception.pkl
# /kaggle/input/tfidf1/scikitlearn/1/2/tfidf_upload/inference_kaggle.py

# %%
import os
import shutil
import sys

# 1. Define Source (Where your uploaded dataset is)
# verify this path is correct in your sidebar!
UPLOAD = "/kaggle/input/tfidf1/scikitlearn/1/2/tfidf_upload" 

# 2. Recreate Folder Structure
print("Creating folder structure...")
os.makedirs("models/tfidf", exist_ok=True)
os.makedirs("src/tfidf", exist_ok=True)

# 3. Create __init__.py files
# This is crucial for Python to treat these folders as packages
with open("src/__init__.py", "w") as f: pass
with open("src/tfidf/__init__.py", "w") as f: pass

# 4. Copy Files
print("Copying files...")
try:
    # Models
    shutil.copy(f"{UPLOAD}/tfidf_category.pkl",      "models/tfidf/tfidf_category.pkl")
    shutil.copy(f"{UPLOAD}/clf_category.pkl",        "models/tfidf/clf_category.pkl")
    shutil.copy(f"{UPLOAD}/tfidf_misconception.pkl",      "models/tfidf/tfidf_misconception.pkl")
    shutil.copy(f"{UPLOAD}/clf_misconception.pkl",        "models/tfidf/clf_misconception.pkl")
    # (Add other models if they exist in the source)
    
    # Scripts
    shutil.copy(f"{UPLOAD}/preprocess.py",           "src/preprocess.py")
    shutil.copy(f"{UPLOAD}/inference_kaggle.py",     "src/tfidf/inference_kaggle.py")
    
    print("Files copied successfully.")
except FileNotFoundError as e:
    print(f"ERROR: Could not find file. Check your paths.\n{e}")
# Out:
# Creating folder structure...
# Copying files...
# Files copied successfully.

# %%
# 5. Run the Script
# We use PYTHONPATH=. to tell the shell "Look in the current folder for modules"
print("\nRunning Inference...")
# !PYTHONPATH=. python src/tfidf/inference_kaggle.py
# Out:
# Running Inference...
# submission.csv created successfully!

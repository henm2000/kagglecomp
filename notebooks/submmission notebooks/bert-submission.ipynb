# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/map-charting-student-math-misunderstandings/sample_submission.csv
# /kaggle/input/map-charting-student-math-misunderstandings/train.csv
# /kaggle/input/map-charting-student-math-misunderstandings/test.csv
# /kaggle/input/deberta-inference/pytorch/default/12/inference_kaggle.py
# /kaggle/input/deberta-v3-small/pytorch/default/1/deberta_category_fold4.pt
# /kaggle/input/deberta-v3-small/pytorch/default/1/preprocess.py
# /kaggle/input/deberta-v3-small/pytorch/default/1/deberta_misconception_fold5.pt
# /kaggle/input/deberta-v3-small/pytorch/default/1/deberta_misconception_fold1.pt
# /kaggle/input/deberta-v3-small/pytorch/default/1/deberta_misconception_fold2.pt
# /kaggle/input/deberta-v3-small/pytorch/default/1/deberta_category_fold1.pt
# /kaggle/input/deberta-v3-small/pytorch/default/1/deberta_category_fold2.pt
# /kaggle/input/deberta-v3-small/pytorch/default/1/deberta_category_fold5.pt
# /kaggle/input/deberta-v3-small/pytorch/default/1/deberta_misconception_fold4.pt
# ...

# %%
import os
import shutil
import sys

# 1. Define Source (Where your uploaded dataset is)
# verify this path is correct in your sidebar!
UPLOAD = "/kaggle/input/deberta-v3-small/pytorch/default/1"

# 2. Recreate Folder Structure
print("Creating folder structure...")
os.makedirs("models/deberta", exist_ok=True)
os.makedirs("src/deberta", exist_ok=True)

# 3. Create __init__.py files
# This is crucial for Python to treat these folders as packages
with open("src/__init__.py", "w") as f: pass
with open("src/deberta/__init__.py", "w") as f: pass

# 4. Copy Files
print("Copying files...")
try:
    # Models
    shutil.copy(f"{UPLOAD}/deberta_category_fold1.pt",      "models/deberta/deberta_category_fold1.pt")
    shutil.copy(f"{UPLOAD}/deberta_category_fold2.pt",      "models/deberta/deberta_category_fold2.pt")
    shutil.copy(f"{UPLOAD}/deberta_category_fold3.pt",      "models/deberta/deberta_category_fold3.pt")
    shutil.copy(f"{UPLOAD}/deberta_category_fold4.pt",      "models/deberta/deberta_category_fold4.pt")
    shutil.copy(f"{UPLOAD}/deberta_category_fold5.pt",      "models/deberta/deberta_category_fold5.pt")
    shutil.copy(f"{UPLOAD}/deberta_misconception_fold1.pt", "models/deberta/deberta_misconception_fold1.pt")
    shutil.copy(f"{UPLOAD}/deberta_misconception_fold2.pt", "models/deberta/deberta_misconception_fold2.pt")
    shutil.copy(f"{UPLOAD}/deberta_misconception_fold3.pt", "models/deberta/deberta_misconception_fold3.pt")
    shutil.copy(f"{UPLOAD}/deberta_misconception_fold4.pt", "models/deberta/deberta_misconception_fold4.pt")
    shutil.copy(f"{UPLOAD}/deberta_misconception_fold5.pt", "models/deberta/deberta_misconception_fold5.pt")
    # (Add other models if they exist in the source)
    
    # Scripts
    shutil.copy(f"{UPLOAD}/preprocess.py",           "src/preprocess.py")
    shutil.copy(f"/kaggle/input/deberta-inference/pytorch/default/12/inference_kaggle.py",     "src/deberta/inference_kaggle.py")
    
    print("Files copied successfully.")
except FileNotFoundError as e:
    print(f"ERROR: Could not find file. Check your paths.\n{e}") /kaggle/working/src/deberta/inference_kaggle.py
# Out:
# Creating folder structure...
# Copying files...
# Files copied successfully.

# %%
# 5. Run the Script
# We use PYTHONPATH=. to tell the shell "Look in the current folder for modules"
print("\nRunning Inference...")
# !PYTHONPATH=. python /kaggle/working/src/deberta/inference_kaggle.py
# Out:
# Running Inference...
# 2025-12-19 16:20:15.153566: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766161215.571941      50 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766161215.697667      50 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766161216.821858      50 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
